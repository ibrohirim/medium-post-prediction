# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler

# %%
file = pd.read_csv('./articles.csv')
df = pd.DataFrame(file)

# %%
df = df.drop(['author', 'link'], axis=1)

# %%
def convert_to_float(string):
    num = 0;
    if 'K' in string:
        num = string[:-1]
        num = float(num)
        num = num * 1000    
        return num
    else: 
        return float(string)

# %%
for val in df.claps:
    newVal = convert_to_float(val)
    df = df.replace(to_replace=val, value=newVal)

# %%
tfidf_title = TfidfVectorizer()
tfidf_text = TfidfVectorizer()
scaler = MinMaxScaler()

# %%
df['title'] = df['title'].apply(lambda v: tfidf_title.fit_transform([v]).toarray().flatten())
df['text'] = df['text'].apply(lambda v: tfidf_text.fit_transform([v]).toarray().flatten())
reshaped = np.array(df['reading_time']).reshape(-1, 1)
df['reading_time'] = scaler.fit_transform(reshaped)

# %%
print(df)
# Out:
#       claps  reading_time                                              title  \
# 0    8300.0      0.310345  [0.2773500981126146, 0.2773500981126146, 0.277...
# 1    1400.0      0.172414  [0.3333333333333333, 0.3333333333333333, 0.333...
# 2    2800.0      0.310345  [0.35355339059327373, 0.35355339059327373, 0.3...
# 3    1300.0      0.172414  [0.2886751345948129, 0.2886751345948129, 0.288...
# 4     935.0      0.310345  [0.4082482904638631, 0.4082482904638631, 0.408...
# ..      ...           ...                                                ...
# 332  3400.0      0.206897  [0.22941573387056174, 0.22941573387056174, 0.2...
# 333  2800.0      0.379310  [0.31622776601683794, 0.31622776601683794, 0.3...
# 334  5800.0      0.068966  [0.3333333333333333, 0.3333333333333333, 0.333...
# 335  3900.0      0.172414  [0.3333333333333333, 0.3333333333333333, 0.333...
# 336  2400.0      0.379310  [0.35355339059327373, 0.35355339059327373, 0.3...
#
# ...

# %%
y = df.claps
df = df.drop('claps', axis=1)

# %%
y = y.to_numpy()

# %%
y = y.reshape(-1, 1)

y = scaler.fit_transform(y)

df = df.to_numpy()

X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=1)
# Out:
# [[1.56587860e-01]
#  [2.63967245e-02]
#  [5.28123172e-02]
#  [2.45098964e-02]
#  [1.76229740e-02]
#  [3.77176928e-02]
#  [4.33781769e-02]
#  [4.73593841e-03]
#  [1.76607106e-02]
#  [4.33781769e-02]
#  [1.13209683e-04]
#  [1.88682805e-05]
#  [1.37719580e-01]
#  [6.60370950e-01]
#  [2.67910715e-01]
#  [2.86778996e-01]
#  [9.05658597e-01]
#  [6.22464575e-02]
#  [1.96211249e-01]
#  [1.99984905e-01]
#  [6.41502670e-01]
#  [1.05662371e-03]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [8.26430687e-03]
#  [6.86805411e-03]
#  [9.43414027e-05]
#  [7.92467782e-04]
#  [3.77365611e-05]
#  [6.20766430e-03]
#  [3.50950018e-03]
#  [3.77365611e-05]
#  [3.77365611e-05]
#  [1.69814525e-04]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [6.60370950e-01]
#  [2.26230684e-02]
#  [6.94352724e-03]
#  [7.92467782e-04]
#  [2.11324742e-03]
#  [2.16985226e-03]
#  [3.58497330e-04]
#  [8.30204343e-04]
#  [1.88682805e-05]
#  [4.52838733e-04]
#  [1.86795977e-02]
#  [3.96045208e-02]
#  [1.11700221e-02]
#  [1.76795789e-02]
# ...

# %%
y_train = y_train.reshape(y_train.shape[0],)
y_train.shape
# Out:
# (269,)

# %%
model = GaussianNB()

# %%
#y_pred = model.fit(X_train, y_train).predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-213-687b741ed835> in <module>
# ----> 1 y_pred = model.fit(X_train, y_train).predict(X_test)
#
# ~/opt/anaconda2/envs/py37/lib/python3.7/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     206         y = column_or_1d(y, warn=True)
#     207         return self._partial_fit(X, y, np.unique(y), _refit=True,
# --> 208                                  sample_weight=sample_weight)
#     209
#     210     def _check_X(self, X):
#
# ~/opt/anaconda2/envs/py37/lib/python3.7/site-packages/sklearn/naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
# ...

# %%
print(X_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-234-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
